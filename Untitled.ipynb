# %%
from qiskit_machine_learning.datasets import *
from qiskit import QuantumCircuit
from qiskit.aqua.components.optimizers import COBYLA, ADAM, SPSA, SLSQP, POWELL, L_BFGS_B, TNC, AQGD
from qiskit.circuit.library import ZZFeatureMap, ZFeatureMap, PauliFeatureMap, RealAmplitudes
from qiskit.quantum_info import Statevector

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\aqua\__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')

# %%
# constants
n = 4
RANDOM_STATE = 42
LR = 1e-3
class_labels = ['yes', 'no']
OUTPUT_PATH = "output/figures/"
DATA_PATH = "data/processed/data.csv"
VAR_DEPTH = 5

# %%
def normalizeData(DATA_PATH = DATA_PATH):
    """
    Normalizes the data
    """
    # Reads the data
    data = pd.read_csv(DATA_PATH)
    data = shuffle(data, random_state=RANDOM_STATE)
    X, Y = data[['sex', 'cp', 'exang', 'oldpeak']].values, data['num'].values
    # normalize the data
    X = normalize(X)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=RANDOM_STATE)
    return X_train, X_test, Y_train, Y_test

# %%
X_train, X_test, Y_train, Y_test = normalizeData()

# %% [markdown]
# as feature_map can be choose:
#  - ZZFeaturemap
#  - ZFeaturemap
#  - PauliFeaturemap
# with a repetition of 1,3 or 5
#
# as variational form (var form) try to vary the repetitions between 1,2 and 4

# %%
sv = Statevector.from_label('0' * n)
feature_map = ZZFeatureMap(4, reps=4) # ZZFeatureMap, ZFeatureMap, PauliFeatureMap
var_form = RealAmplitudes(n, reps=VAR_DEPTH)
circuit = feature_map.combine(var_form)
circuit.draw(output='mpl', filename=OUTPUT_PATH+"overallcircuit.png")

# %%
def get_data_dict(params, x):
    """
    Assign the params to the variational circuit and the data to the featuremap
    :param params: Parameter for training the variational circuit
    :param x: The data
    :return parameters:
    """
    parameters = {}
    for i, p in enumerate(feature_map.ordered_parameters):
        parameters[p] = x[i]
    for i, p in enumerate(var_form.ordered_parameters):
        parameters[p] = params[i]
    return parameters

# %% [markdown]
# Below function is based on
# https://arxiv.org/abs/1804.11326

# %%
def assign_label(bit_string, class_labels):
    """
    Based on the output from measurements assign no if it odd parity and yes if it is even parity
    :param bit_string: The bit string eg 00100
    :return class_label: Yes or No
    """
    hamming_weight = sum([int(k) for k in list(bit_string)])
    is_odd_parity = hamming_weight & 1
    if is_odd_parity:
        return class_labels[1]
    else:
        return class_labels[0]

# %%
def return_probabilities(counts, class_labels):
    """
    Calculates the probabilities of the class label after assigning the label from the bit string measured
    as output
    :type counts: dict
    :param counts: The counts from the measurement of the quantum circuit
    :return result: The probability of each class
    """
    shots = sum(counts.values())
    result = {class_labels[0]: 0,
    class_labels[1]: 0}
    for key, item in counts.items():
        label = assign_label(key, class_labels)
        result[label] += counts[key]/shots
    return result

# %%
def classify(x_list, params, class_labels):
    """
    Assigns the x and params to the quantum circuit the runs a measurement to return the probabilities
    of each class
    :type params: List
    :type x_list: List
    :param x_list: The x data
    :param params: Parameters for optimizing the variational circuit
    :return probs: The probabilities
    """
    qc_list = []
    for x in x_list:
        circ_ = circuit.assign_parameters(get_data_dict(params, x))
        qc = sv.evolve(circ_)
        qc_list += [qc]
        probs = []
    for qc in qc_list:
        counts = qc.probabilities_dict()
        prob = return_probabilities(counts, class_labels)
        probs += [prob]
    return probs

# %%
def mse_cost(probs, expected_label):
    p = probs.get(expected_label)
    actual, pred = np.array(1), np.array(p)
    return np.square(np.subtract(actual,pred)).mean()

# %%
cost_list = []
def cost_function(X, Y, class_labels, params, shots=100, print_value=False):
    # map training input to list of labels and list of samples
    cost = 0
    training_labels = []
    training_samples = []
    for sample in X:
        training_samples += [sample]
    for label in Y:
        if label == 0:
            training_labels += [class_labels[0]]
        elif label == 1:
            training_labels += [class_labels[1]]
    probs = classify(training_samples, params, class_labels)
    # evaluate costs for all classified samples
    for i, prob in enumerate(probs):
        cost += mse_cost(prob, training_labels[i])
    cost /= len(training_samples)
    # print resulting objective function
    if print_value:
        print('%.4f' % cost)
    # return objective value
    cost_list.append(cost)
    return cost

# %%
cost_list = []
optimizer = SPSA(max_trials=50)

# define objective function for training
objective_function = lambda params: cost_function(X_train, Y_train, class_labels, params, print_value=True)
# randomly initialize the parameters
np.random.seed(RANDOM_STATE)
init_params = 2*np.pi*np.random.rand(n*(VAR_DEPTH)*2)
# train classifier
opt_params, value, _ = optimizer.optimize(len(init_params), objective_function, initial_point=init_params)
# print results
print()
print('opt_params:', opt_params)
print('opt_value: ', value)
# Out:
# {'0000': 0.016736693085560507, '0001': 0.03451714767033187, '0010': 0.0412321207245517, '0011': 0.02076320419031556, '0100': 0.012968193647689575, '0101': 0.17504263808447101, '0110': 0.0015072807250376533, '0111': 0.059629535877192705, '1000': 0.020303236291967775, '1001': 0.033941695003006436, '1010': 0.11200803319249306, '1011': 0.11021861937158468, '1100': 0.033129055066402624, '1101': 0.2975980338628691, '1110': 0.02893083807452069, '1111': 0.0014736751320024175}
# {'0000': 0.004395827822990163, '0001': 0.0326236693299831, '0010': 0.08773578384945693, '0011': 0.10206897595784997, '0100': 0.0738914113664531, '0101': 0.023096875404504977, '0110': 0.013031261896179265, '0111': 0.013768749445533711, '1000': 0.030341583248195893, '1001': 0.0317115464146164, '1010': 0.12193182947076149, '1011': 0.06796617355135459, '1100': 0.013467949828491017, '1101': 0.010739948645427435, '1110': 0.23527313093753638, '1111': 0.13795528283066283}
# {'0000': 0.01850069499622254, '0001': 0.08813715378276472, '0010': 0.09069280698774382, '0011': 0.008042209085894954, '0100': 0.013143098198817683, '0101': 0.13850210836548799, '0110': 0.017170707182940826, '0111': 0.028231691781819116, '1000': 0.002822253504321991, '1001': 0.00022840890107092454, '1010': 0.28592152057024595, '1011': 0.018575291561064976, '1100': 0.11443526461010833, '1101': 0.0971615059970749, '1110': 0.030598108886679735, '1111': 0.04783717558773752}
# {'0000': 0.016736693085560507, '0001': 0.03451714767033187, '0010': 0.0412321207245517, '0011': 0.02076320419031556, '0100': 0.012968193647689575, '0101': 0.17504263808447101, '0110': 0.0015072807250376533, '0111': 0.059629535877192705, '1000': 0.020303236291967775, '1001': 0.033941695003006436, '1010': 0.11200803319249306, '1011': 0.11021861937158468, '1100': 0.033129055066402624, '1101': 0.2975980338628691, '1110': 0.02893083807452069, '1111': 0.0014736751320024175}
# {'0000': 0.01704476548746569, '0001': 0.0014962618976800278, '0010': 0.005237867048128704, '0011': 0.1510447720466026, '0100': 0.08999362092513614, '0101': 0.006218846184121129, '0110': 0.03372834625791465, '0111': 0.11479616670151342, '1000': 0.08107721718979076, '1001': 0.0004273195382086416, '1010': 0.0271156995023183, '1011': 0.01943323365648605, '1100': 0.04162818824286529, '1101': 0.26490962645854743, '1110': 0.13859088608088535, '1111': 0.007257182782332813}
# {'0000': 0.014942275367781623, '0001': 0.10685536792928112, '0010': 0.08857003522405933, '0011': 0.0388380531093015, '0100': 0.05868360704848543, '0101': 0.0006759607054266007, '0110': 0.0342693276040871, '0111': 0.03782973454706468, '1000': 0.1527916314529324, '1001': 0.028445178860658126, '1010': 0.08950522002282245, '1011': 0.06308729597303965, '1100': 0.048332219187399474, '1101': 0.07400965070677927, '1110': 0.15953447201907786, '1111': 0.0036299702418003056}
# {'0000': 0.016736693085560507, '0001': 0.03451714767033187, '0010': 0.0412321207245517, '0011': 0.02076320419031556, '0100': 0.012968193647689575, '0101': 0.17504263808447101, '0110': 0.0015072807250376533, '0111': 0.059629535877192705, '1000': 0.020303236291967775, '1001': 0.033941695003006436, '1010': 0.11200803319249306, '1011': 0.11021861937158468, '1100': 0.033129055066402624, '1101': 0.2975980338628691, '1110': 0.02893083807452069, '1111': 0.0014736751320024175}
# {'0000': 0
# {'0000': 0.0032252134682733643, '0001': 0.03572336491695199, '0010': 0.099681531569006, '0011': 0.031114722802801503, '0100': 0.01149031891172055, '0101': 0.15928619263151608, '0110': 0.011686521362563554, '0111': 0.06025936862621585, '1000': 0.056772016266807904, '1001': 0.0026349949870521938, '1010': 0.07523827393853506, '1011': 0.11469943018544518, '1100': 0.00553322154581055, '1101': 0.3024525701565219, '1110': 0.029797812813037197, '1111': 0.00040444581773849304}
# {'0000': 0.042423081542039116, '0001': 0.05365510879134707, '0010': 0.11197570743273863, '0011': 0.02513162381851062, '0100': 0.038002352804981904, '0101': 0.10128093791237595, '0110': 0.1106651229740495, '0111': 0.055175253392968165, '1000': 0.07754510962876568, '1001': 0.09477066119130531, '1010': 0.03756439362499746, '1011': 0.10732296050398707, '1100': 0.022580455180988265, '1101': 0.0152604302207251, '1110': 0.028820823944212568, '1111': 0.07782597703600536}
# {'0000': 0.04361618027176795, '0001': 0.009883778611427654, '0010': 0.040261248936186336, '0011': 0.003163051029257576, '0100': 0.10606373867972863, '0101': 0.09289262383523321, '0110': 0.1593958274781457, '0111': 0.02366031989050967, '1000': 0.08641895187101238, '1001': 0.015561088141167889, '1010': 0.052350432086095855, '1011': 0.06253505092913515, '1100': 0.03263649061476142, '1101': 0.05437241030133079, '1110': 0.13203589478101535, '1111': 0.08515291254322127}
# {'0000': 0.0036191437466745278, '0001': 0.02243109825072102, '0010': 0.05208817542878139, '0011': 0.06257699494579297, '0100': 0.18875634211326614, '0101': 0.008946074086410327, '0110': 0.09814770956040503, '0111': 0.07847137436445997, '1000': 0.06423840222535704, '1001': 0.03505983841783544, '1010': 0.19357294652670426, '1011': 0.003025706921492661, '1100': 0.10130481042240697, '1101': 0.037783211053923384, '1110': 0.007778260324614049, '1111': 0.04219991161115172}
# 0.2858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9032/1603013278.py in <module>
#       8 init_params = 2*np.pi*np.random.rand(n*(VAR_DEPTH)*2)
#       9 # train classifier
# ---> 10 opt_params, value, _ = optimizer.optimize(len(init_params), objective_function, initial_point=init_params)
#      11 # print results
#      12 print()
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\aqua\components\optimizers\spsa.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     123             # at least one calibration, at most 25 calibrations
#     124             num_steps_calibration = min(25, max(1, self._maxiter // 5))
# --> 125             self._calibration(objective_function, initial_point, num_steps_calibration)
#     126         else:
#     127             logger.debug('Skipping calibration, parameters used as provided.')
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\aqua\components\optimizers\spsa.py in _calibration(self, obj_fun, initial_theta, stat)
#     241                 obj_plus, obj_minus = obj_fun(np.concatenate((theta_plus, theta_minus)))
#     242             else:
# --> 243                 obj_plus = obj_fun(theta_plus)
#     244                 obj_minus = obj_fun(theta_minus)
#     245             delta_obj += np.absolute(obj_plus - obj_minus) / stat
#
# ~\AppData\Local\Temp/ipykernel_9032/1603013278.py in <lambda>(params)
#       3
#       4 # define objective function for training
# ----> 5 objective_function = lambda params: cost_function(X_train, Y_train, class_labels, params, print_value=True)
#       6 # randomly initialize the parameters
#       7 np.random.seed(RANDOM_STATE)
#
# ~\AppData\Local\Temp/ipykernel_9032/2260748071.py in cost_function(X, Y, class_labels, params, shots, print_value)
#      12         elif label == 1:
#      13             training_labels += [class_labels[1]]
# ---> 14     probs = classify(training_samples, params, class_labels)
#      15     # evaluate costs for all classified samples
#      16     for i, prob in enumerate(probs):
#
# ~\AppData\Local\Temp/ipykernel_9032/3486693405.py in classify(x_list, params, class_labels)
#      12     for x in x_list:
#      13         circ_ = circuit.assign_parameters(get_data_dict(params, x))
# ---> 14         qc = sv.evolve(circ_)
#      15         qc_list += [qc]
#      16         probs = []
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\quantum_info\states\statevector.py in evolve(self, other, qargs)
#     313         # Evolution by a circuit or instruction
#     314         if isinstance(other, QuantumCircuit):
# --> 315             other = other.to_instruction()
#     316         if isinstance(other, Instruction):
#     317             if self.num_qubits is None:
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\quantumcircuit.py in to_instruction(self, parameter_map, label)
#    1257         from qiskit.converters.circuit_to_instruction import circuit_to_instruction
#    1258
# -> 1259         return circuit_to_instruction(self, parameter_map, label=label)
#    1260
#    1261     def to_gate(self, parameter_map=None, label=None):
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\converters\circuit_to_instruction.py in circuit_to_instruction(circuit, parameter_map, equivalence_library, label)
#      85     instruction.condition = None
#      86
# ---> 87     target = circuit.assign_parameters(parameter_dict, inplace=False)
#      88
#      89     if equivalence_library is not None:
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\utils\deprecation.py in wrapper(*args, **kwargs)
#      60             if kwargs:
#      61                 _rename_kwargs(func.__name__, kwargs, kwarg_map)
# ---> 62             return func(*args, **kwargs)
#      63
#      64         return wrapper
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\quantumcircuit.py in assign_parameters(self, parameters, inplace, param_dict)
#    2161             bound_circuit = self
#    2162         else:
# -> 2163             bound_circuit = self.copy()
#    2164             self._increment_instances()
#    2165             bound_circuit._name_update()
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\quantumcircuit.py in copy(self, name)
#    1870         instr_instances = {id(instr): instr for instr, _, __ in self._data}
#    1871
# -> 1872         instr_copies = {id_: instr.copy() for id_, instr in instr_instances.items()}
#    1873
#    1874         cpy._parameter_table = ParameterTable(
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\quantumcircuit.py in <dictcomp>(.0)
#    1870         instr_instances = {id(instr): instr for instr, _, __ in self._data}
#    1871
# -> 1872         instr_copies = {id_: instr.copy() for id_, instr in instr_instances.items()}
#    1873
#    1874         cpy._parameter_table = ParameterTable(
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\instruction.py in copy(self, name)
#     418             updated if it was provided
#     419         """
# --> 420         cpy = self.__deepcopy__()
#     421
#     422         if name:
#
# c:\Users\enric\Documents\GitHub\quantum_programming\myenv\lib\site-packages\qiskit\circuit\instruction.py in __deepcopy__(self, _memo)
#     428         cpy._params = copy.copy(self._params)
#     429         if self._definition:
# --> 430             cpy._definition = copy.deepcopy(self._definition, _memo)
#     431         return cpy
#     432
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~\AppData\Local\Programs\Python\Python39\lib\copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# KeyboardInterrupt:
